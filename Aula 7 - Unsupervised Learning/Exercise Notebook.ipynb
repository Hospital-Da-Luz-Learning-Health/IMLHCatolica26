# %% [markdown]
# # Class 4: Exercise Notebook - Unsupervised Learning

# %% [markdown]
# ## Dataset: Pima Indians Diabetes Database
#
# Data source and documentation [here](https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database?resource=download&select=diabetes.csv)
#
# Data summary:
# | **Column**                 | **Description**                                                        |
# |----------------------------|------------------------------------------------------------------------|
# | **Pregnancies**            | Number of times pregnant                                               |
# | **Glucose**                | Plasma glucose concentration a 2 hours in an oral glucose tolerance test|
# | **BloodPressure**          | Diastolic blood pressure (mm Hg)                                       |
# | **SkinThickness**          | Triceps skin fold thickness (mm)                                       |
# | **Insulin**                | 2-Hour serum insulin (mu U/ml)                                         |
# | **BMI**                    | Body mass index (weight in kg/(height in m)^2)                         |
# | **DiabetesPedigreeFunction** | Diabetes pedigree function                                           |
# | **Age**                    | Age (years)                                                            |
# | **Outcome**                | Class variable (0 or 1) 268 of 768 are 1, the others are 0             |

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load Data

# %%
# In google colab you may need to add the csv file to the files folder --> you can download it from the folder "data"
data_url = 'https://raw.githubusercontent.com/Hospital-Da-Luz-Learning-Health/IMLHCatolica26/main/Aula%205%20-%20Supervised%20Learning%20II/data/diabetes.csv'
data = pd.read_csv(data_url)

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# dataframe shape
data.shape
# Out:
# (768, 9)

# %%
# check missing values
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# Let's check how the dataset looks like -> This can be an example of how to explore the variables

# %%
fig, axs = plt.subplots(4, 2, figsize=(15,14))
axs = axs.flatten()
n_bins = 50

for i,col in enumerate(data.columns[:-1]):
    bins = np.arange(data[col].min(), data[col].max(), (data[col].max() - data[col].min()) / n_bins)
    sns.histplot(data[data['Outcome']==0][col],bins = bins,color='#38b000',ax=axs[i], stat='percent', label='No Disease')
    sns.histplot(data[data['Outcome']==1][col],bins = bins,color='#f0a794',ax=axs[i], stat='percent', label='Disease')
 
plt.show()

# %%
plot_x = 'Glucose'
plot_y = 'BMI'

plt.figure(figsize=(10, 6))

ax = sns.scatterplot(
    data=data,
    x=plot_x,
    y=plot_y,
    hue='Outcome',
    palette={0: 'blue', 1: 'red'},
    alpha=0.5,
)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, ['Healthy', 'Diabetic'], title='Outcome')

# %%
# Separate features and labels
X = data.drop('Outcome', axis=1)

# %% [markdown]
# ### Standardize the dataset

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ## K-means

# %% [markdown]
# ### Exercise 1:
#
# Determine the optimal number of clusters using the silhouette score.
#
# **Note:** This is a real dataset, consider the nuances of the silhouette score!

# %%
# Define the range of k values to test
#k_values = ...
#silhouette_scores = []

# %%
# Compute K-Means clustering and calculate silhouette score for each k
#for k in k_values:
#    ...

# %%
# Plotting the Silhouette scores
plt.figure(figsize=(6, 4))
#plt.plot(k_values, silhouette_scores, marker='o')
#plt.xlabel('Number of clusters (k)')
#plt.ylabel('Silhouette score')
#plt.title('Silhouette score for Optimal k')
#plt.grid(True)
plt.show()

# %% [markdown]
# ### Exercise 2:
#
# Compute the percentage of diabetic cases per cluster for the optimal number of clusters and visualize the phenotypes

# %%
# Fit K-Means for k clusters
#kmeans = KMeans(...
#cluster_labels = ...

# Add cluster labels to the original dataframe
#data['Cluster'] = ...

# %%
# Compute the percentage of diabetic cases (Outcome == 1) per cluster
# cluster_summary = 
# cluster_summary['Percentage_heart_disease'] = ...
cluster_summary.T

# %%
# Visualize the variables and describe insights

# %% [markdown]
# ### Exercise 3 (Optional):
#
# Prove statistical differences between clusters
